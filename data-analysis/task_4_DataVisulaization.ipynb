# %%
import pandas as pd

# %%
DATA=pd.read_csv("/content/Bike Prices.csv")
display(DATA)
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
display(DATA.columns)
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %% [markdown]
# names of the collumns

# %%
display(DATA.head())
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0

# %% [markdown]
# first 5 row's

# %%
display(DATA.tail())
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 1056  1st owner      40000                NaN
# 1057  1st owner      17000                NaN
# 1058  1st owner      16000                NaN
# 1059  1st owner      50000                NaN
# 1060  1st owner      60000                NaN

# %% [markdown]
# last 5 row's

# %%
display(DATA.shape)
# Out:
# (1061, 8)

# %% [markdown]
# give total no of row(1061) & collumn(8)

# %%
display(DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB
# None

# %% [markdown]
# information about dataframe

# %%
display(DATA.describe())
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %% [markdown]
# give dataset (mean,median,minimum,miximum)etc

# %%
display(DATA.duplicated().sum())
# Out:
# np.int64(6)

# %%
display(DATA.isnull().sum())
# Out:
# Brand                  0
# Model                  0
# Selling_Price          0
# Year                   0
# Seller_Type            0
# Owner                  0
# KM_Driven              0
# Ex_Showroom_Price    435
# dtype: int64

# %% [markdown]
# find missing value(sum of the value)
# missing value(Ex_Showroom_Price:435)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
colors=["#dc143c","#d2691e","#7fffd4","#00ffef","#191970"]

# %%
DATA
# Out:
#       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# 0     1st owner       8000            30490.0
# ...

# %%
DATA.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %%
plt.hist(DATA['Selling_Price'],color='#40e0d0')
plt.title("selling price")
plt.xlabel("selling price")
plt.show()

# %%
plt.boxplot(DATA["Selling_Price"])
plt.show()

# %%
a=['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner','KM_Driven', 'Ex_Showroom_Price']
for i in a:
  sns.histplot(DATA[i],kde=True,color="#cc00cc",bins=20)
  print("****")
  plt.show()
# Out:
# ****
# ****
# ****
# ****
# ****
# ****
# ****
# ****

# %%
sns.countplot(DATA['Brand'],color='#8b008b')
# Out:
# <Axes: xlabel='count', ylabel='Brand'>

# %%
plt.pie(DATA['Owner'].value_counts(),colors=colors)
plt.show()

# %%
plt.pie(DATA['Owner'].value_counts(),labels=DATA['Owner'].value_counts().index)
plt.show()

# %%
DATA.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %%
sns.scatterplot(x='Selling_Price',y='Ex_Showroom_Price',data=DATA,color='#000080')
plt.show()

# %%
sns.barplot(x='Selling_Price',y='Ex_Showroom_Price',data=DATA,color='#0033aa')
plt.show()

# %%
sns.lineplot(x='Selling_Price',y='Ex_Showroom_Price',data=DATA,color='#1c1cf0')
plt.show()

# %%
sns.pairplot(DATA)
